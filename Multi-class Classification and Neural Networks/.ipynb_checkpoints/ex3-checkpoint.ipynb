# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.io as sio
from scipy import optimize
import math
# %matplotlib inline

# %%
data = sio.loadmat('data/ex3data1.mat')

# %%
X = data['X']
y = data['y']
m, _ = X.shape
input_layer_size  = 400  # 20x20 Input Images of Digits
num_labels = 10

# %%
# Randomly select 100 data points to display
rand_indices = np.random.permutation(range(m))
sel = X[rand_indices[0:100], :]

# %%
from displayData import displayData
displayData(sel)
# Out:
# /Users/andy/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /Users/andy/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:190: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   a = empty(shape, dtype, order)
# displayData.py:38: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   display_array[min(rows):max(rows), min(cols):max(cols)] = X[curr_ex, :].reshape(example_height, example_width) / max_val

# %% [markdown]
# Training One-vs-All Logistic Regression...

# %%
Lambda = 0.1

# %%
def sigmoid(z):
    return 1 / (1 + math.e ** -z)

# %%
def lrCostFunction(theta, X, y, Lambda):
    H = sigmoid(X.dot(theta))
    T = (-y* np.log(H)) - (1 - y) * (np.log(1 - H))
    J = np.sum(T) / len(y) + Lambda / (2 * len(y)) * np.sum(theta[1:] ** 2)
    print J
    return J

# %%
def oneVsAll(X, y, num_labels, Lambda):
    X = np.column_stack((np.ones((X.shape[0],1)),X))
    all_theta = np.zeros((num_labels, X.shape[1]))
    for i in range(1):
        initial_theta = np.zeros(X.shape[1],)
        options = {'full_output': True, 'maxiter': 50}
        theta, _, _, _, _ = optimize.fmin(lambda t: lrCostFunction(t, X, 1*(y==i), Lambda), initial_theta, **options)
        all_theta[i] = theta
        print i
    return all_theta

# %%
# %timeit all_theta = oneVsAll(X, y, num_labels, Lambda)
# Out:
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5000625  0.5000625  0.5000625 ...,  0.5000625  0.5000625  0.5000625]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# [ 0.5  0.5  0.5 ...,  0.5  0.5  0.5]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-c1c11b22f8ca> in <module>()
# ----> 1 get_ipython().magic(u'timeit all_theta = oneVsAll(X, y, num_labels, Lambda)')
#
# /Users/andy/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2161         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2162         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2163         return self.run_line_magic(magic_name, magic_arg_s)
#    2164
#    2165     #-------------------------------------------------------------------------
#
# /Users/andy/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2082                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2083             with self.builtin_trap:
# -> 2084                 result = fn(*args,**kwargs)
#    2085             return result
#    2086
#
# <decorator-gen-59> in timeit(self, line, cell)
#
# /Users/andy/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/andy/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#    1039             number = 1
#    1040             for _ in range(1, 10):
# -> 1041                 time_number = timer.timeit(number)
#    1042                 worst_tuning = max(worst_tuning, time_number / number)
#    1043                 if time_number >= 0.2:
#
# /Users/andy/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, number)
#     135         gc.disable()
#     136         try:
# --> 137             timing = self.inner(it, self.timer)
#     138         finally:
#     139             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <ipython-input-39-b6f56dce0e85> in oneVsAll(X, y, num_labels, Lambda)
#       5         initial_theta = np.zeros(X.shape[1],)
#       6         options = {'full_output': True, 'maxiter': 50}
# ----> 7         theta, _, _, _, _ = optimize.fmin(lambda t: lrCostFunction(t, X, 1*(y==i), Lambda), initial_theta, **options)
#       8         all_theta[i] = theta
#       9         print i
#
# /Users/andy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback)
#     375             'return_all': retall}
#     376
# --> 377     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     378     if full_output:
#     379         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# /Users/andy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in _minimize_neldermead(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, return_all, **unknown_options)
#     444
#     445         sim[k + 1] = y
# --> 446         f = func(y)
#     447         fsim[k + 1] = f
#     448
#
# /Users/andy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     283     def function_wrapper(*wrapper_args):
#     284         ncalls[0] += 1
# --> 285         return function(*(wrapper_args + args))
#     286
#     287     return ncalls, function_wrapper
#
# <ipython-input-39-b6f56dce0e85> in <lambda>(t)
#       5         initial_theta = np.zeros(X.shape[1],)
#       6         options = {'full_output': True, 'maxiter': 50}
# ----> 7         theta, _, _, _, _ = optimize.fmin(lambda t: lrCostFunction(t, X, 1*(y==i), Lambda), initial_theta, **options)
#       8         all_theta[i] = theta
#       9         print i
#
# <ipython-input-41-74b5b2c1f638> in lrCostFunction(theta, X, y, Lambda)
#       2     H = sigmoid(X.dot(theta))
#       3     T = (-y* np.log(H)) - (1 - y) * (np.log(1 - H))
# ----> 4     J = np.sum(T) / len(y) + Lambda / (2 * len(y)) * np.sum(theta[1:] ** 2)
#       5     print H
#       6     return J
#
# /Users/andy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1838     else:
#    1839         return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1840                              out=out, keepdims=keepdims)
#    1841
#    1842
#
# /Users/andy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
all_theta.shape

# %%
def predictOneVsAll(all_theta, X):
    X = np.column_stack((np.ones((X.shape[0],1)),X))
    C = sigmoid(X.dot(all_theta.T))
    print X.shape
    print C.shape
    print np.max(C) * 2

# %%
pred = predictOneVsAll(all_theta, X)

# %%
all_theta[:,30]
