# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = scipy.io.loadmat('data/ex8data1.mat')

# %%
X = data['X']
Xval = data['Xval']
yval = data['yval'].flatten()
X[:5]
# Out:
# array([[ 13.04681517,  14.74115241],
#        [ 13.40852019,  13.7632696 ],
#        [ 14.19591481,  15.85318113],
#        [ 14.91470077,  16.17425987],
#        [ 13.57669961,  14.04284944]])

# %%
plt.plot(X[:,0],X[:,1], 'bx')
plt.grid(True)
plt.axis = ([0, 30, 0 ,30])
plt.xlabel('Latency (ms)')
plt.ylabel('Throughput (mb/s)')

# %%
def estimateGaussian(X):
    return X.mean(axis=0), X.std(axis=0) ** 2
mu, sigma = estimateGaussian(X)
print mu
print sigma
# Out:
# [ 14.11222578  14.99771051]
# [ 1.35374717  1.3075723 ]

# %%
def multivariateGaussian(X, mu, sigma):
    k = len(mu)

    if sigma.ndim == 1:
        sigma = np.diag(sigma)

    X = X - mu
    p = (2 * np.pi) ** (- k / 2) * np.linalg.det(sigma) ** (-0.5) * \
        np.exp(-0.5 * np.sum(X.dot(np.linalg.pinv(sigma))*X, axis=1))

    return p
p = multivariateGaussian(X, mu, sigma)
p[:5]
# Out:
# array([ 0.07670299,  0.05563173,  0.09019049,  0.05554427,  0.07592789])

# %%
from math import isinf


def visualizeFit(X, mu, sigma2):
    """
    This visualization shows you the
    probability density function of the Gaussian distribution. Each example
    has a location (x1, x2) that depends on its feature values.
    """
    n = np.linspace(0,35,71)
    X1 = np.meshgrid(n,n)
    Z = multivariateGaussian(np.column_stack((X1[0].T.flatten(), X1[1].T.flatten())),mu,sigma2)
    Z = Z.reshape(X1[0].shape)

    plt.figure(figsize=(7,7))
    plt.plot(X[:, 0], X[:, 1],'bx')
    # Do not plot if there are infinities
    if not isinf(np.sum(Z)):
        plt.contour(X1[0], X1[1], Z, 10.0**np.arange(-20, 0, 3).T)
        plt.xlabel('Latency (ms)')
        plt.ylabel('Throughput (mb/s)')
        plt.grid(True)
        
visualizeFit(X,  mu, sigma)
plt.show()

# %%
pval = multivariateGaussian(Xval, mu, sigma)
pval
# Out:
# array([  4.21866437e-02,   1.05598843e-01,   4.21536395e-02,
#          7.31651619e-02,   8.76816832e-02,   4.40572495e-02,
#          6.95281009e-02,   1.09439981e-01,   1.69087767e-02,
#          9.69883611e-02,   1.02275232e-01,   4.35846092e-02,
#          5.89609376e-02,   1.05199422e-02,   6.15383174e-02,
#          4.61282276e-02,   4.53841179e-02,   6.46133921e-02,
#          9.61494488e-02,   4.83714560e-02,   1.15073852e-01,
#          3.39475562e-02,   1.10200992e-01,   8.97059198e-02,
#          9.15057684e-02,   1.07458876e-01,   4.58062264e-02,
#          8.80797825e-02,   4.36823551e-02,   8.16675512e-02,
#          1.08130558e-01,   7.45898143e-02,   8.69818248e-02,
#          1.17569526e-01,   7.53300226e-02,   8.89759318e-02,
#          7.95730357e-02,   2.08739232e-02,   6.17148530e-02,
#          1.14574616e-01,   6.41574640e-02,   3.46477602e-02,
#          7.47941006e-02,   1.09110896e-01,   1.18001410e-01,
#          9.29379532e-02,   3.61703551e-02,   1.11321490e-01,
#          9.41932796e-02,   7.38181576e-02,   5.32561718e-02,
#          1.18376562e-01,   9.57142872e-02,   9.76246871e-02,
#          5.13697274e-02,   8.68632280e-02,   8.81987847e-02,
#          6.74797178e-02,   3.89742424e-02,   7.99780271e-02,
#          3.19325205e-02,   1.02420095e-01,   3.21152753e-02,
#          1.75518603e-02,   1.06681221e-01,   4.49059142e-02,
#          4.44894586e-02,   1.06938869e-01,   1.19034135e-01,
#          4.83922199e-02,   1.11530995e-01,   2.13153072e-02,
#          9.30668205e-02,   9.66139817e-02,   8.07396395e-02,
#          5.17762265e-02,   1.11788896e-01,   7.04512497e-02,
#          8.61413401e-02,   9.40108092e-02,   7.04278589e-02,
#          5.86711275e-02,   4.36122874e-03,   2.11461686e-02,
#          1.12126819e-01,   5.90360829e-02,   5.53536112e-02,
#          1.12984831e-01,   2.24896163e-02,   1.96736807e-02,
#          1.05701930e-01,   8.87725665e-02,   2.48094635e-02,
#          1.30615816e-04,   2.52685486e-02,   2.99975682e-02,
#          1.03316939e-01,   7.63773091e-02,   9.42132882e-02,
#          2.44012117e-02,   1.01878953e-01,   3.04496907e-02,
#          1.06171423e-01,   1.55607188e-02,   4.57936588e-02,
#          7.67404230e-02,   5.98920954e-02,   1.14556834e-01,
#          8.70372711e-03,   8.74049320e-02,   7.87360377e-02,
#          1.13623176e-01,   9.48340455e-02,   6.64222108e-02,
#          7.43822259e-02,   5.30603079e-02,   1.08572355e-01,
#          2.01513817e-02,   6.35206227e-02,   1.03597752e-01,
#          1.05330753e-01,   4.69268087e-02,   2.00355356e-02,
#          6.29527276e-02,   7.26527147e-02,   8.98195455e-02,
#          6.12246355e-02,   8.81335021e-02,   4.23257621e-02,
#          6.70045291e-02,   1.47715849e-02,   5.16298614e-02,
#          4.49120763e-02,   8.02247129e-02,   2.62069787e-02,
#          1.07063621e-01,   1.05123027e-01,   1.12355327e-01,
#          1.09251472e-01,   2.29196341e-02,   4.94840719e-02,
#          9.24451802e-02,   5.12325540e-02,   6.32276017e-02,
#          8.10182075e-02,   7.90474276e-02,   8.01608784e-02,
#          4.74424603e-09,   8.11004410e-07,   1.53595906e-47,
#          2.76142549e-42,   5.33314326e-07,   2.91746167e-13,
#          1.09258578e-06])

# %%
def selectThreshold(yval, pval):
    bestEpsilon = 0;
    bestF1 = 0;
    F1 = 0;

    stepsize = (np.max(pval) - np.min(pval)) / 1000;
    for epsilon in np.arange(np.min(pval),np.max(pval), stepsize):
        predictions = pval < epsilon
        tp = np.sum((predictions == 1) & (yval==1), dtype=np.float)
        fp = np.sum((predictions == 1) & (yval==0), dtype=np.float)
        fn = np.sum((predictions == 0) & (yval==1), dtype=np.float)
        prec = tp / (tp + fp);
        rec = tp / (tp + fn);
        F1 = 2 * prec * rec / (prec + rec);
        
        if F1 > bestF1:
           bestF1 = F1
           bestEpsilon = epsilon

    return bestEpsilon, bestF1
epsilon, F1 = selectThreshold(yval, pval)
print epsilon, F1
# Out:
# 0.000119618291861 0.875
# /Users/andy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: RuntimeWarning: invalid value encountered in double_scalars

# %%
outliers = np.where(p < epsilon)[0]
print outliers[:5]

# %%
visualizeFit(X,  mu, sigma)
plt.plot(X[outliers, 0], X[outliers, 1], 'r^',)
plt.show()

# %%
data = scipy.io.loadmat('data/ex8data2.mat')

# %%
X = data['X']
Xval = data['Xval']
yval = data['yval'].flatten()
X[:5]

# %%
mu, sigma = estimateGaussian(X)
p = multivariateGaussian(X, mu, sigma)
pval = multivariateGaussian(Xval, mu, sigma)
epsilon, F1 = selectThreshold(yval, pval)
print epsilon, F1

# %%
print np.sum(p < epsilon)
